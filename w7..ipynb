# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('/content/gdrive/MyDrive/Software Project v/SPV.csv')

# %%
df.head()
# Out:
#   Order ID Order Date CustomerName  ...      Sub-Category gender  year of order
# 0  B-25601   1/4/2012       Bharat  ...         Bookcases      f           2012
# 1  B-25602   1/4/2013        Pearl  ...             Stole      f           2013
# 2  B-25603   3/4/2014        Jahan  ...       Hankerchief      f           2014
# 3  B-25604   3/4/2015       Divsha  ...  Electronic Games      f           2015
# 4  B-25605   5/4/2011      Kasheen  ...            Phones      m           2011
#
# [5 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.plot(x,y)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[11,22,33,44]
fig,ax=plt.subplots(figsize=(5,6))
ax.plot(x,y)
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")
plt.savefig('figurse/sample-plot.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-66-737f04642597> in <module>()
#       9        xlabel="x-axis",
#      10        ylabel="y-axis")
# ---> 11 plt.savefig('figurse/sample-plot.png')
#      12
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ...

# %%
x=np.linspace(0,10,100)
x[:10]

# %%
fig,ax=plt.subplots(figsize=(5,4))
ax.plot(x,x**2)

# %%
fig,ax=plt.subplots(figsize=(5,4))
ax.scatter(x,np.exp(x))

# %%
fig,ax=plt.subplots(figsize=(5,4))
ax.scatter(x,np.sin(x))

# %%
fig,ax=plt.subplots(figsize=(5,4))
ax.scatter(x,np.cos(x))

# %%
product_price={"Furniture":1275,
               "Clothing":300,
               "Electronics":2617}
fig,ax=plt.subplots(figsize=(5,4))
ax.bar(product_price.keys(),product_price.values());
ax.set(title="TESLA STORE",
       ylabel="Price ($)")
# Out:
# [Text(0, 0.5, 'Price ($)'), Text(0.5, 1.0, 'TESLA STORE')]

# %%
fig,ax=plt.subplots(figsize=(5,4))
ax.barh(list(product_price.keys()),list(product_price.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
x=np.random.randn(1000)
fig,ax=plt.subplots(figsize=(5,4))
ax.hist(x)
# Out:
# (array([  7.,  28.,  83., 169., 232., 224., 163.,  65.,  26.,   3.]),
#  array([-3.06134377, -2.44841702, -1.83549027, -1.22256352, -0.60963677,
#          0.00328998,  0.61621673,  1.22914347,  1.84207022,  2.45499697,
#          3.06792372]),
#  <a list of 10 Patch objects>)
